# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/ENB2012_data.xlsx - Φύλλο1.csv')
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.rename(columns={'X1':'Relative Compactness','X2':'Surface Area','X3':'Wall Area','X4':'Roof Area','X5':'Overall Height','X6':'Orientation',
           'X7':'Glazing Area','X8':'Glazing Area Distribution','Y1':'HL','Y2':'CL'},inplace=True)

# %%
df.head()
# Out:
#    Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                  0.98         514.5      294.0     110.25             7.0
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    Orientation  Glazing Area  Glazing Area Distribution     HL     CL
# 0            2           0.0                          0  15.55  21.33
# 1            3           0.0                          0  15.55  21.33
# 2            4           0.0                          0  15.55  21.33
# 3            5           0.0                          0  15.55  21.33
# 4            2           0.0                          0  20.84  28.28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Relative Compactness       768 non-null    float64
#  1   Surface Area               768 non-null    float64
#  2   Wall Area                  768 non-null    float64
#  3   Roof Area                  768 non-null    float64
#  4   Overall Height             768 non-null    float64
#  5   Orientation                768 non-null    int64
#  6   Glazing Area               768 non-null    float64
#  7   Glazing Area Distribution  768 non-null    int64
#  8   HL                         768 non-null    float64
#  9   CL                         768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.describe()
# Out:
#        Relative Compactness  Surface Area   Wall Area   Roof Area  \
# count            768.000000    768.000000  768.000000  768.000000
# mean               0.764167    671.708333  318.500000  176.604167
# std                0.105777     88.086116   43.626481   45.165950
# min                0.620000    514.500000  245.000000  110.250000
# 25%                0.682500    606.375000  294.000000  140.875000
# 50%                0.750000    673.750000  318.500000  183.750000
# 75%                0.830000    741.125000  343.000000  220.500000
# max                0.980000    808.500000  416.500000  220.500000
#
#        Overall Height  Orientation  Glazing Area  Glazing Area Distribution  \
# count       768.00000   768.000000    768.000000                  768.00000
# mean          5.25000     3.500000      0.234375                    2.81250
# std           1.75114     1.118763      0.133221                    1.55096
# ...

# %% [markdown]
# # EDA

# %%
for i in df.columns[:8]:
  print(df[i].unique())
# Out:
# [0.98 0.9  0.86 0.82 0.79 0.76 0.74 0.71 0.69 0.66 0.64 0.62]
# [514.5 563.5 588.  612.5 637.  661.5 686.  710.5 735.  759.5 784.  808.5]
# [294.  318.5 343.  416.5 245.  269.5 367.5]
# [110.25 122.5  147.   220.5 ]
# [7.  3.5]
# [2 3 4 5]
# [0.   0.1  0.25 0.4 ]
# [0 1 2 3 4 5]

# %%
plt.figure(figsize=(14,6))
plt.title('Distribution of Relative Compactness')
sns.countplot(df['Relative Compactness'],palette='ocean')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Relative Compactness'].value_counts()
# Out:
# 0.98    64
# 0.90    64
# 0.86    64
# 0.82    64
# 0.79    64
# 0.76    64
# 0.74    64
# 0.71    64
# 0.69    64
# 0.66    64
# 0.64    64
# 0.62    64
# Name: Relative Compactness, dtype: int64

# %% [markdown]
# __Relative Compactness follows Uniform Distribution__

# %%
plt.figure(figsize=(14,6))
plt.title('Distribution of Surface Area')
sns.countplot(df['Surface Area'],palette='spring')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Surface Area'].value_counts()
# Out:
# 514.5    64
# 563.5    64
# 588.0    64
# 612.5    64
# 637.0    64
# 661.5    64
# 686.0    64
# 710.5    64
# 735.0    64
# 759.5    64
# 784.0    64
# 808.5    64
# Name: Surface Area, dtype: int64

# %% [markdown]
# __Surface area also follows uniform distribution and has 12 different surface areas of buildings__

# %%
plt.figure(figsize=(14,6))
plt.title('Distribution of Wall Area')
sns.countplot(df['Wall Area'],palette='winter')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Wall Area'].value_counts()
# Out:
# 294.0    192
# 318.5    192
# 343.0    128
# 416.5     64
# 245.0     64
# 269.5     64
# 367.5     64
# Name: Wall Area, dtype: int64

# %% [markdown]
# __Wall Area follows normal distribution with a max count for 294.0 and 318.5__

# %%
plt.figure(figsize=(14,6))
plt.title('Distribution of Roof Area')
sns.countplot(df['Roof Area'],palette='summer')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# __The Roof area of 220.5 has max counts__

# %%
plt.figure(figsize=(14,6))
plt.title('Distribution of Overall Height')
sns.countplot(df['Overall Height'],palette='rocket')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Overall Height'].value_counts()
# Out:
# 7.0    384
# 3.5    384
# Name: Overall Height, dtype: int64

# %% [markdown]
# __Overall height follows uniform distribution with equal number of 7.0 and 3.5 heights__

# %%
plt.figure(figsize=(14,6))
plt.title('Distribution of Glazing Area')
sns.countplot(df['Glazing Area'],palette='magma')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Glazing Area'].value_counts()
# Out:
# 0.10    240
# 0.25    240
# 0.40    240
# 0.00     48
# Name: Glazing Area, dtype: int64

# %% [markdown]
# __Glazing Area follows uniformity except for 0__

# %%
plt.figure(figsize=(14,6))
plt.title('Glazing Area Distribution')
sns.countplot(df['Glazing Area Distribution'],palette='Blues')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Glazing Area Distribution'].value_counts()
# Out:
# 1    144
# 2    144
# 3    144
# 4    144
# 5    144
# 0     48
# Name: Glazing Area Distribution, dtype: int64

# %% [markdown]
# __it is similiar to Glazing area__

# %%
plt.xlabel('Heating Load')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Heating Load')
sns.distplot(x=df['HL'],bins=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# __For Heating Load, the loads 10-15 have greater distribution__

# %%
plt.xlabel('Cooling Load')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Cooling Load')
sns.distplot(x=df['CL'],bins=20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# __Similiarly for cooling load, the range 10-15 loads has maximum distribution__

# %%
plt.figure(figsize=(14,6))
df1 = df.groupby('Relative Compactness')['HL'].mean().to_frame()
df1.reset_index(inplace=True)
sns.barplot(x='Relative Compactness', y='HL',data=df1,palette='summer')

# %% [markdown]
# __As RC increases, the HL decreases first and recahes a maximum point at 0.79 RC__

# %%
plt.figure(figsize=(14,6))
df1 = df.groupby('Relative Compactness')['CL'].mean().to_frame()
df1.reset_index(inplace=True)
sns.barplot(x='Relative Compactness', y='CL',data=df1,palette='winter')

# %% [markdown]
# __CL also has the same relationship as the HL with RC__

# %%
plt.figure(figsize=(14,6))
df1 = df.groupby('Surface Area')['HL'].mean().to_frame()
df1.reset_index(inplace=True)
sns.barplot(x='Surface Area', y='HL',data=df1,palette='spring')

# %%
plt.figure(figsize=(14,6))
df1 = df.groupby('Surface Area')['CL'].mean().to_frame()
df1.reset_index(inplace=True)
sns.barplot(x='Surface Area', y='CL',data=df1,palette='autumn')

# %%
df.hist(bins=10,figsize=(20,10))
plt.show()

# %%
sns.pairplot(df, kind="scatter", diag_kind='kde')

# %%
corr = df.corr()
corr
# Out:
#                            Relative Compactness  Surface Area     Wall Area  \
# Relative Compactness               1.000000e+00 -9.919015e-01 -2.037817e-01
# Surface Area                      -9.919015e-01  1.000000e+00  1.955016e-01
# Wall Area                         -2.037817e-01  1.955016e-01  1.000000e+00
# Roof Area                         -8.688234e-01  8.807195e-01 -2.923165e-01
# Overall Height                     8.277473e-01 -8.581477e-01  2.809757e-01
# Orientation                        4.678592e-17 -3.459372e-17 -2.429499e-17
# Glazing Area                      -2.960552e-15  3.636925e-15 -8.567455e-17
# Glazing Area Distribution         -7.107006e-16  2.438409e-15  2.067384e-16
# HL                                 6.222722e-01 -6.581202e-01  4.556712e-01
# CL                                 6.343391e-01 -6.729989e-01  4.271170e-01
#
#                               Roof Area  Overall Height   Orientation  \
# ...

# %%
plt.figure(figsize=(14,8))
sns.heatmap(corr, cmap='Reds', annot=True)

# %% [markdown]
# # Model Building

# %%
X = df.drop(columns=['HL','CL'])
y= df[['HL','CL']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression().fit(X_train, y_train)
y_predict = lr.predict(X_train)
print('Accuracy of Linear Regression on training set: {:.2f}'
     .format(lr.score(X_train, y_train)))
print('Accuracy of Linear Regression on test set: {:.2f}'
     .format(lr.score(X_test, y_test)))
# Out:
# Accuracy of Linear Regression on training set: 0.90
# Accuracy of Linear Regression on test set: 0.90

# %%
print("lr.coef_: {}".format(lr.coef_))

print("lr.intercept_: {}".format(lr.intercept_))
# Out:
# lr.coef_: [[-23.22208794  -9.12209329   0.95163216 -12.90294941  14.06618023
#    -0.15025552   7.85913976   1.18321625]
#  [-26.71604972 -10.9230715   -1.71918832 -13.22694887  14.03429415
#     0.15811777   5.6586116    0.30475867]]
# lr.intercept_: [31.52572189 39.12595239]

# %%
from sklearn.multioutput import MultiOutputRegressor
multiOutput_linear = MultiOutputRegressor(lr,n_jobs=-1)
multiOutput_linear.fit(X_train,y_train)
train_r2_score=r2_score(y_train,multiOutput_linear.predict(X_train))
test_r2_score=r2_score(y_test,multiOutput_linear.predict(X_test))
output = pd.DataFrame(index=None, columns=['model','train_r2_score','test_r2_score'])
output = output.append(pd.Series({'model':'Linear Regressor', 'train_r2_score':train_r2_score,'test_r2_score':test_r2_score}),ignore_index=True )
output
# Out:
#               model  train_r2_score  test_r2_score
# 0  Linear Regressor        0.900867       0.903599

# %% [markdown]
# ## KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors': [2,4,6,8,10,12]}
knn = KNeighborsRegressor()
grid_search = GridSearchCV(knn,param_grid,cv=5)
grid_search.fit(X_train, y_train)
grid_search.best_params_
# Out:
# {'n_neighbors': 8}

# %%
knn = KNeighborsRegressor(n_neighbors=8).fit(X_train, y_train)
print('Accuracy of Knn Regressor on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of Knn Regressor on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of Knn Regressor on training set: 0.93
# Accuracy of Knn Regressor on test set: 0.92

# %%
param_grid = {'weights':['distance', 'uniform'], 'n_neighbors':range(3,75)}
grid_search_knn = MultiOutputRegressor(GridSearchCV(KNeighborsRegressor(), param_grid, cv=5,return_train_score=True))
grid_search_knn.fit(X_train, y_train)
train_r2_score=r2_score(y_train,grid_search_knn.predict(X_train))
test_r2_score=r2_score(y_test,grid_search_knn.predict(X_test))
output = output.append(pd.Series({'model':'KNN Regressor', 'train_r2_score':train_r2_score,'test_r2_score':test_r2_score}),ignore_index=True )
output
# Out:
#               model  train_r2_score  test_r2_score
# 0  Linear Regressor        0.900867       0.903599
# 1     KNN Regressor        0.931093       0.922609

# %% [markdown]
# ## Ridge

# %%
from sklearn.linear_model import Ridge
ridge = Ridge().fit(X_train,y_train)
param_grid = {'alpha':[0.01, 1, 5, 10, 100]}
grid_search = GridSearchCV(ridge, param_grid, cv = 5)
grid_search.fit(X_train, y_train)
print('Best parameters: {}'.format(grid_search.best_params_))
# Out:
# Best parameters: {'alpha': 0.01}

# %%
ridge = Ridge(alpha=0.01).fit(X_train, y_train)
print('Accuracy of Ridge Regressor on training set: {:.2f}'
     .format(ridge.score(X_train, y_train)))
print('Accuracy of Ridge Regressor on test set: {:.2f}'
     .format(ridge.score(X_test, y_test)))
# Out:
# Accuracy of Ridge Regressor on training set: 0.90
# Accuracy of Ridge Regressor on test set: 0.90

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(max_iter = 10000).fit(X_train,y_train)
param_grid = {'alpha':[0.01, 1, 5, 10, 100]}
grid_search = GridSearchCV(lasso, param_grid, cv = 5)
grid_search.fit(X_train, y_train)
print('Best parameters: {}'.format(grid_search.best_params_))
# Out:
# Best parameters: {'alpha': 0.01}

# %%
lasso = Lasso(max_iter = 10000, alpha=0.01).fit(X_train,y_train)
print("Number of features used: {}".format(np.sum(lasso.coef_ != 0)))
print('Accuracy of Lasso Regressor on training set: {:.2f}'
     .format(lasso.score(X_train, y_train)))
print('Accuracy of Lasso Regressor on test set: {:.2f}'
     .format(lasso.score(X_test, y_test)))
# Out:
# Number of features used: 14
# Accuracy of Lasso Regressor on training set: 0.90
# Accuracy of Lasso Regressor on test set: 0.90

# %% [markdown]
# ## DT Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
param_grid = {'max_depth': [2, 4, 6 ,8, 10]}
grid_search = GridSearchCV(dt, param_grid,cv=5)
grid_search.fit(X_train,y_train)
grid_search.best_params_
# Out:
# {'max_depth': 6}

# %%
dt = DecisionTreeRegressor(max_depth=6).fit(X_train, y_train)
print('Accuracy of DT Regressor on training set: {}'
     .format(dt.score(X_train, y_train)))
print('Accuracy of Dt Regressor on test set: {}'
     .format(dt.score(X_test, y_test)))
# Out:
# Accuracy of DT Regressor on training set: 0.9856855756403593
# Accuracy of Dt Regressor on test set: 0.9791526133393011

# %%
model = DecisionTreeRegressor(max_depth=6)

train_r2_score=r2_score(y_train,dt.predict(X_train))
test_r2_score=r2_score(y_test,dt.predict(X_test))
output = output.append(pd.Series({'model':'Decision Tree Regressor', 'train_r2_score':train_r2_score,'test_r2_score':test_r2_score}),ignore_index=True )
output
# Out:
#                      model  train_r2_score  test_r2_score
# 0         Linear Regressor        0.900867       0.903599
# 1            KNN Regressor        0.931093       0.922609
# 2  Random Forest Regressor        0.997715       0.984944
# 3  Decision Tree Regressor        0.985686       0.979153

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
param_grid = {'max_features': [2,4,6,8],
            'max_depth': [2,4,6,8],
           'max_leaf_nodes':[2,4,6,8]}
rf = RandomForestRegressor(random_state=10)
grid_search = GridSearchCV(rf,param_grid,cv=5)
grid_search.fit(X_train, y_train)
grid_search.best_params_
# Out:
# {'max_depth': 6, 'max_features': 4, 'max_leaf_nodes': 8}

# %%
rf = RandomForestRegressor(max_depth= 4, max_features=6, max_leaf_nodes=8, random_state=10).fit(X_train, y_train)
print('Accuracy of RF Regressor on training set: {:.2f}'
     .format(rf.score(X_train, y_train)))
print('Accuracy of Rf Regressor on test set: {:.2f}'
     .format(rf.score(X_test, y_test)))
# Out:
# Accuracy of RF Regressor on training set: 0.95
# Accuracy of Rf Regressor on test set: 0.94

# %%
model = RandomForestRegressor( random_state=5, n_estimators= 700, n_jobs = -1)

param_grid = {'max_features':['auto', 'log2'], 'max_depth':[5,10,15,20,30,50,60]}

grid_search_rf = MultiOutputRegressor(GridSearchCV(model, param_grid, cv= 5,return_train_score=True))
grid_search_rf.fit(X_train, y_train)
train_r2_score=r2_score(y_train,grid_search_rf.predict(X_train))
test_r2_score=r2_score(y_test,grid_search_rf.predict(X_test))
output = output.append(pd.Series({'model':'Random Forest Regressor', 'train_r2_score':train_r2_score,'test_r2_score':test_r2_score}),ignore_index=True )
output
# Out:
#                      model  train_r2_score  test_r2_score
# 0         Linear Regressor        0.900867       0.903599
# 1            KNN Regressor        0.931093       0.922609
# 2  Random Forest Regressor        0.997715       0.984944

# %% [markdown]
# ## Ensemble of all the regressors

# %%
lr=LinearRegression()
knn=KNeighborsRegressor(n_neighbors=8)
dt = DecisionTreeRegressor(max_depth= 6)
rf = RandomForestRegressor(max_depth= 4, max_features=6, max_leaf_nodes=8)

# %%
from mlxtend.regressor import StackingRegressor
stregr = StackingRegressor(regressors=[lr, knn, rf,dt], 
                           meta_regressor=dt)
stregr.fit(X_train, y_train)
str_predict = stregr.predict(X_test)
print('Accuracy of STR Regressor on training set: {:.3f}'
     .format(stregr.score(X_train, y_train)))
print('Accuracy of STR Regressor on test set: {:.3f}'
     .format(stregr.score(X_test, y_test)))
# Out:
# Accuracy of STR Regressor on training set: 0.993
# Accuracy of STR Regressor on test set: 0.980

# %%
from sklearn.metrics import (mean_squared_error,
                             mean_absolute_error,
                             median_absolute_error,
                             explained_variance_score,
                             r2_score)

# %%
print(f'Mean Squared Error: {round(mean_squared_error(y_test, str_predict, squared=False), 3)}')
print(f'Mean Absolute Error: {round(mean_absolute_error(y_test, str_predict), 3)}')
print(f'Median Absolute Error: {round(median_absolute_error(y_test, str_predict), 3)}')
print(f'Explained Variance Score: {round(explained_variance_score(y_test, str_predict), 3)}')
print(f'R2 Score: {round(r2_score(y_test, str_predict, multioutput= "variance_weighted"), 3)}')
# Out:
# Mean Squared Error: 1.242
# Mean Absolute Error: 0.741
# Median Absolute Error: 0.368
# Explained Variance Score: 0.98
# R2 Score: 0.981

# %%
plt.scatter(y_test['HL'], pd.DataFrame(str_predict)[0])
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Heating Load Predictions')

plt.plot(y_test, y_test, color='Magenta')

# %%
plt.scatter(y_test['CL'], pd.DataFrame(str_predict)[1])
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Cooling LoadPredictions')

plt.plot(y_test, y_test, color='Magenta')

# %% [markdown]
# # Modelling on Efficiency

# %%
# The total load is the sum of the individual heating and cooling load
df['Overall_load'] = df['HL'] + Z['CL']
df['Effeciency'] = 1

df.loc[df.Overall_load < 42,['Effeciency']] = 0
df.loc[df.Overall_load > 70 , ['Effeciency']] = 2

#Efficiency classes
y_clf = df['Effeciency']

# %%
X_train_clf, X_test_clf, y_train_clf, y_test_clf = train_test_split(X,y_clf , random_state = 5)

from sklearn.preprocessing import MinMaxScaler
MinMax = MinMaxScaler(feature_range= (0,1))
X_train_class = MinMax.fit_transform(X_train_clf)
X_test_class = MinMax.transform(X_test_clf)

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Logistic Regression

# %%
param_grid = {'C':[0.01, 0.1, 0.5, 1, 2, 5, 10, 15, 20]}

model = LogisticRegression()

grid_search = GridSearchCV(model, param_grid, cv=10)
grid_search.fit(X_train_clf, y_train_clf)

print('Best parameters for efficiency classification {}'.format(grid_search.best_params_))
tr_a = accuracy_score(y_train_clf, grid_search.predict(X_train_clf))
te_a = accuracy_score(y_test_clf, grid_search.predict(X_test_clf))

eff = pd.DataFrame(index=None, columns=['model','train_accuracy','test_accuracy'])
eff = eff.append(pd.Series({'model':'Logistic Regressor', 'train_accuracy':tr_a,'test_accuracy':te_a}),
                       ignore_index=True )
eff
# Out:
# Best parameters for efficiency classification {'C': 0.01}
#                 model  train_accuracy  test_accuracy
# 0  Logistic Regressor        0.859375        0.84375

# %%
## Random Forest

# %%
param_grid = {'max_features':['auto', 'log2'], 'max_depth':[5,10,15,20,50,60]}

model = RandomForestClassifier(n_estimators= 700, n_jobs = -1, random_state = 5)

grid_search_RF_Class = GridSearchCV(model, param_grid, cv=5)
grid_search_RF_Class.fit(X_train_clf, y_train_clf)

print('Best parameters for efficiency classification {}'.format(grid_search_RF_Class.best_params_))

tr_a = accuracy_score(y_train_clf, grid_search_RF_Class.predict(X_train_clf))
te_a = accuracy_score(y_test_clf, grid_search_RF_Class.predict(X_test_clf))

eff = eff.append(pd.Series({'model':'Random Forest Classifier', 'train_accuracy':tr_a,'test_accuracy':te_a}),
                       ignore_index=True )
eff
# Out:
# Best parameters for efficiency classification {'max_depth': 10, 'max_features': 'log2'}
#                       model  train_accuracy  test_accuracy
# 0        Logistic Regressor        0.859375       0.843750
# 1  Random Forest Classifier        1.000000       0.989583

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
param_grid = {'max_features':['auto', 'log2'], 'max_depth':[5,10,15,20,50,60], 'learning_rate':[0.01,0.1,0.7,1]}

model =  GradientBoostingClassifier(random_state = 5, n_estimators = 500)


grid_search_GB_Class = GridSearchCV(model, param_grid, cv=5)
grid_search_GB_Class.fit(X_train_clf, y_train_clf)

print('Best parameters for efficiency classification {}'.format(grid_search_GB_Class.best_params_))

tr_a = accuracy_score(y_train_clf, grid_search_GB_Class.predict(X_train_clf))
te_a = accuracy_score(y_test_clf, grid_search_GB_Class.predict(X_test_clf))

eff = eff.append(pd.Series({'model':'Gradient Boosting Classifier', 'train_accuracy':tr_a,'test_accuracy':te_a}),
                       ignore_index=True )
eff
# Out:
# Best parameters for efficiency classification {'learning_rate': 0.01, 'max_depth': 5, 'max_features': 'log2'}
#                           model  train_accuracy  test_accuracy
# 0            Logistic Regressor        0.859375       0.843750
# 1      Random Forest Classifier        1.000000       0.989583
# 2      Random Forest Classifier        1.000000       0.989583
# 3  Gradient Boosting Classifier        1.000000       0.989583

# %% [markdown]
# # Neural Network Classification Model

# %%
from keras.models import Sequential
from keras.layers import Dense

# fix random seed for reproducibility
np.random.seed(5)

# %%
from keras.utils import np_utils

# convert integers to dummy variables (i.e. one hot encoded)
y_train = np_utils.to_categorical(y_train_clf)
y_test = np_utils.to_categorical(y_test_clf)

# %%
from keras.wrappers.scikit_learn import KerasClassifier

def model_classifier():
    #create model
    model = Sequential()
    model.add(Dense(8, input_dim=8, activation='relu'))
    model.add(Dense(4, activation='relu')) #hidden layer
    model.add(Dense(3,activation='sigmoid')) #output layer
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
param_grid = {'epochs':[50, 200] , 'batch_size':[10, 50, 100]}

model = KerasClassifier(build_fn = model_classifier , verbose = 0)

grid_search_Keras_Class = GridSearchCV(model , param_grid , cv =10)

grid_search_Keras_Class.fit(X_train_clf, y_train)

print('Best parameters for efficiency classification {}'.format(grid_search_Keras_Class.best_params_))
# Out:
# Best parameters for efficiency classification {'batch_size': 10, 'epochs': 200}

# %%
from sklearn.metrics import accuracy_score
print('The Train Accuracy score is',accuracy_score(y_train_clf, grid_search_Keras_Class.predict(X_train_clf)))
print('The Test Accuracy score is',accuracy_score(y_test_clf, grid_search_Keras_Class.predict(X_test_clf)))
# Out:
# The Train Accuracy score is 0.859375
# The Test Accuracy score is 0.84375
